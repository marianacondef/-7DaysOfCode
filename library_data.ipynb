# %% [markdown]
# ## Day 1 - Importando dados

# %%
import pandas as pd

# %% [markdown]
# ### Carregando dados

# %%
url_base = 'Datasets/dados_emprestimos/emprestimos-{}{}.csv'
anos = range(2010, 2020)
semestres = [1, 2]

data_frames = {}

for ano in anos:
    for semestre in semestres:
        formatted_ano_semestre = f'{ano}{semestre}'
        url = url_base.format(ano, semestre)
        data_frames[formatted_ano_semestre] = pd.read_csv(url)

# %% [markdown]
# ### Concatenando os dados

# %%
emprestimos = pd.concat(data_frames, ignore_index=True)
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2231452        2962504    2008047075  2020/01/13 23:27:18.346000000
# 2231453        2962505    2014078494  2020/01/13 23:27:18.327000000
# 2231454        2962506    2018014453  2020/01/13 23:27:18.302000000
# 2231455        2962507    2010073307                            NaN
# 2231456        2962508    2010094374                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ### Verificando e excluindo duplicatas

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
emprestimos.drop_duplicates()
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 8               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2231452        2962504    2008047075  2020/01/13 23:27:18.346000000
# 2231453        2962505    2014078494  2020/01/13 23:27:18.327000000
# 2231454        2962506    2018014453  2020/01/13 23:27:18.302000000
# 2231455        2962507    2010073307                            NaN
# 2231456        2962508    2010094374                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %% [markdown]
# ### Importando restante dos dados

# %%
exemplares = pd.read_parquet('Datasets\dados_exemplares.parquet')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
exemplares.value_counts()
# Out:
# id_exemplar  codigo_barras  colecao            biblioteca                                             status_material  localizacao  registro_sistema
# 3            L000001        Acervo Circulante  Biblioteca Central Zila Mamede                         ESPECIAL         638          1                   1
# 1070480      2013071582     Acervo Circulante  Biblioteca Setorial do Centro Ciências da Saúde - CCS  REGULAR          340          200283              1
# 1070506      2013077711     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          354          200288              1
# 1070505      2013077710     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          327          200288              1
# 1070504      2013077807     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          348          200286              1
# ...

# %%
exemplares.drop_duplicates()
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# ### Merge dos DataSets

# %%
dados_emprestimos = emprestimos.merge(exemplares)
dados_emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2046943        2962504    2008047075  2020/01/13 23:27:18.346000000
# 2046944        2962505    2014078494  2020/01/13 23:27:18.327000000
# 2046945        2962506    2018014453  2020/01/13 23:27:18.302000000
# 2046946        2962507    2010073307                            NaN
# 2046947        2962508    2010094374                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## Day 2 - Limpeza dos dados

# %% [markdown]
# ### Organização dos itens por CDU (classificação decimal universal)

# %%
CDU = []

for cdu in dados_emprestimos['localizacao']:
    if cdu in range(0,100):
        CDU.append("Generalidades. Ciência e conhecimento")
    elif cdu in range(100,200):
        CDU.append('Filosofia e psicologia')
    elif cdu in range(200,300):
        CDU.append("Religião")
    elif cdu in range(300,400):
        CDU.append("Ciências sociais")
    elif cdu in range(400,500):
        CDU.append("Classe vaga")
    elif cdu in range(500,600):
        CDU.append("Matemática e ciências naturais")
    elif cdu in range(600,700):
        CDU.append("Ciências aplicadas")
    elif cdu in range(700,800):
        CDU.append("Belas artes")
    elif cdu in range(800,900):
        CDU.append("Linguagem. Língua. Linguística")
    else:
        CDU.append("Geografia. Biografia. História")

dados_emprestimos['classificação'] = CDU
dados_emprestimos.tail()
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 2046943        2962504    2008047075  2020/01/13 23:27:18.346000000
# 2046944        2962505    2014078494  2020/01/13 23:27:18.327000000
# 2046945        2962506    2018014453  2020/01/13 23:27:18.302000000
# 2046946        2962507    2010073307                            NaN
# 2046947        2962508    2010094374                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 2046943  2019/12/30 17:48:52.962000000  2020/01/15 18:52:27.000000000
# 2046944  2019/12/30 17:48:52.998000000  2020/01/15 15:28:51.000000000
# 2046945  2019/12/30 17:48:53.039000000  2020/01/15 15:29:08.000000000
# 2046946  2019/12/30 18:05:30.265000000  2020/01/29 16:05:27.000000000
# 2046947  2019/12/30 18:05:30.313000000  2020/01/29 16:05:36.000000000
#
#          matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 2046943        2.019006e+10      ALUNO DE GRADUAÇÃO       255650
# ...

# %% [markdown]
# ### Tornando coluna "matricula_ou_siape" em string

# %%
dados_emprestimos['matricula_ou_siape'] = dados_emprestimos['matricula_ou_siape'].astype(str)
dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Deletando coluna "registro_sistema"

# %%
dados_emprestimos.drop(columns=['registro_sistema'],inplace=True)
dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ## Day 3 - Análise exploratória de dados e DateTime

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ### Verificando quantidade total de exemplares emprestados por cada ano

# %%
dados_emprestimos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 709705      7
# 709704      7
# 2049407     3
# 10114792    3
# 2014596     3
#            ..
# 1514393     1
# 1514392     1
# 1514391     1
# 1514390     1
# 2962508     1
# Name: count, Length: 2043189, dtype: int64

# %%
emprestimos = dados_emprestimos.groupby('id_emprestimo')
emprestimos = emprestimos.get_group(2014596)
emprestimos
# Out:
#          id_emprestimo codigo_barras data_renovacao  \
# 1145845        2014596    2010082016            NaN
# 1145846        2014596    2010082016            NaN
# 1145847        2014596    2010082016            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 1145845  2015/06/10 18:51:56.994000000  2015/06/22 15:06:49.000000000
# 1145846  2015/06/10 18:51:56.994000000  2015/06/22 15:06:49.000000000
# 1145847  2015/06/10 18:51:56.994000000  2015/06/22 15:06:49.000000000
#
#         matricula_ou_siape tipo_vinculo_usuario  id_exemplar  \
# 1145845        198704783.0              DOCENTE      1055570
# 1145846        198704783.0              DOCENTE      1055922
# 1145847        198704783.0              DOCENTE      1056360
#
#                    colecao                      biblioteca status_material  \
# 1145845  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# Quantidade de empréstimos

# %%
quantidade_emprestimos = len(dados_emprestimos['id_emprestimo'].drop_duplicates())
quantidade_emprestimos
# Out:
# 2043189

# %% [markdown]
# Quantidade de exemplares emprestados

# %%
quantidade_exemplares = len(dados_emprestimos['id_exemplar'])
quantidade_exemplares
# Out:
# 2046948

# %% [markdown]
# ### Análise anual de empréstimos

# %%
quantidade_vs_data = pd.DataFrame(dados_emprestimos['data_emprestimo'].value_counts().reset_index())
quantidade_vs_data.columns = ['data','quantidade']
quantidade_vs_data['data'] = pd.to_datetime(quantidade_vs_data['data'])
quantidade_vs_data
# Out:
#                            data  quantidade
# 0       2010-01-04 09:58:46.549           7
# 1       2010-01-04 09:58:46.522           7
# 2       2017-04-20 21:07:44.036           3
# 3       2010-01-04 09:21:19.099           3
# 4       2018-02-22 10:45:11.523           3
# ...                         ...         ...
# 2043153 2013-05-24 18:47:41.377           1
# 2043154 2013-05-24 18:47:38.243           1
# 2043155 2013-05-24 18:45:23.778           1
# 2043156 2013-05-24 18:44:07.877           1
# 2043157 2019-12-30 18:05:30.313           1
#
# [2043158 rows x 2 columns]

# %%
quantidade_vs_data['data'] = pd.to_datetime(quantidade_vs_data['data'])
quantidade_vs_data['ano'] = quantidade_vs_data['data'].dt.year
emprestimos_por_ano = quantidade_vs_data.groupby('ano')['quantidade'].sum().reset_index()
emprestimos_por_ano
# Out:
#     ano  quantidade
# 0  2010      161412
# 1  2011      196390
# 2  2012      221365
# 3  2013      234749
# 4  2014      219189
# 5  2015      213582
# 6  2016      215918
# 7  2017      218462
# 8  2018      194080
# 9  2019      171801

# %%
quantidade_vs_data['data'] = pd.to_datetime(quantidade_vs_data['data'])
quantidade_vs_data['ano'] = quantidade_vs_data['data'].dt.year
emprestimos_por_ano = quantidade_vs_data.groupby('ano')['quantidade'].sum().reset_index()
emprestimos_por_ano
# Out:
#     ano  quantidade
# 0  2010      161412
# 1  2011      196390
# 2  2012      221365
# 3  2013      234749
# 4  2014      219189
# 5  2015      213582
# 6  2016      215918
# 7  2017      218462
# 8  2018      194080
# 9  2019      171801

# %%
sns.set_theme(context='notebook', 
              style='darkgrid', 
              palette='deep', 
              font_scale=1.3, 
              rc={"figure.figsize":(12,8)})
     

ax = sns.lineplot(data=emprestimos_por_ano,x='ano',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))   

ax.set_title('Quantidade de exemplares emprestados do SISBI anualmente'+'\n',size=20,loc='left',weight='bold')
ax=ax

# %% [markdown]
# Houve uma queda nos empréstimos de 2013 para 2014, após uma alta contínua desde 2010. Desde 2014, a quantidade de empréstimos continuou diminuindo, atingindo maior queda entre 2016 e 2018.
#
# Essa diminuição repentina em 2013 deve ser investigada. Uma das razões para a queda nos empréstimos pode estar relacionada ao aumento da pirataria online de livros, levando a uma menor adesão dos alunos às bibliotecas e meios burocráticos de aquisição dos livros. Outras causas como:
# - Diminuição do marketing da biblioteca
# - Diminuição do número de alunos
# - Não disponibilidade dos livros usados como texto-base
#
# podem também ser investigadas;

# %% [markdown]
# ### Análise mensal dos empréstimos

# %%
quantidade_vs_data['data'] = pd.to_datetime(quantidade_vs_data['data'])
quantidade_vs_data['mês'] = quantidade_vs_data['data'].dt.month
meses = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
quantidade_vs_data['mês'] = quantidade_vs_data['mês'].map(meses)
emprestimos_por_mes = quantidade_vs_data.groupby('mês')['quantidade'].sum()
emprestimos_por_mes = emprestimos_por_mes.reindex(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
emprestimos_por_mes
# Out:
# mês
# Jan     63957
# Feb    199533
# Mar    240837
# Apr    208725
# May    202522
# Jun    138129
# Jul    123790
# Aug    232793
# Sep    208234
# Oct    188410
# Nov    164222
# Dec     75796
# Name: quantidade, dtype: int64

# %%
emprestimos_por_mes = pd.DataFrame(emprestimos_por_mes)

ax = sns.lineplot(data=emprestimos_por_mes,x='mês',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x',rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                

ax.set_title("Quantidade de exemplares emprestados do SISBI por mês"+"\n",size=16,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=255000,fontsize=12, ha='left',color='gray')

ax=ax

# %% [markdown]
# Pelo gráfico acima, observa-se que os mêses com maior índice de empréstimos são *março* e *agosto* e os meses com o menor índice *janeiro*, *julho* e *dezembro*, provavelmente ligado às férias estudantis.
#
# Assim, é razóavel que as férias dos colaboradores sejam organizadas nesses três meses de menor demanda.
#
# Nesses meses, é recomendável realizar atividades administrativas, como inventário e reorganização do sistema de empréstimo, para os colaboradores ativos.

# %% [markdown]
# ### Análise diária dos empréstimos

# %%
quantidade_vs_data['data'] = pd.to_datetime(quantidade_vs_data['data'])
quantidade_vs_data['hora'] = quantidade_vs_data['data'].dt.hour
emprestimos_por_hora = quantidade_vs_data.groupby('hora')['quantidade'].sum().reset_index()
emprestimos_por_hora
# Out:
#     hora  quantidade
# 0      0          17
# 1      6          14
# 2      7       18567
# 3      8      102387
# 4      9      129758
# 5     10      183416
# 6     11      177530
# 7     12      146736
# 8     13      125089
# 9     14      148996
# 10    15      164427
# 11    16      207954
# 12    17      183140
# 13    18      180326
# 14    19      101163
# 15    20      126522
# 16    21       50608
# 17    22         247
# 18    23          51

# %%
emprestimos_por_hora = emprestimos_por_hora.sort_values(ascending=True,by='quantidade')
plt.figure(figsize=[12,8])
ax = sns.barplot(data=emprestimos_por_hora,y='quantidade',x='hora',
                 palette='Blues',hue='quantidade',dodge=False)   
ax.set(xlabel='Horário',ylabel=None)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
ax.set_title("Quantidade de exemplares emprestados por faixa horária"+"\n",size=16,loc='left',weight='bold')
ax.text(s='Período de 2010 a 2020',x=-0.5,y=224000,fontsize=12, ha='left',color='gray')
ax=ax

# %% [markdown]
# Nota-se que os períodos de pico durante o dia ocorrem entre às 10h e às 16h. Assim, é razoável que as atividades de não-atendimento direto ao público ocorram em horários de menos presença dos alunos. Os horários das 21h em diante são os mais vagos, notando-se também um menor pico no começo da manhã, até às 8h.

# %% [markdown]
# ## Day 4 - Análise exploratória de dados e Variáveis categóricas

# %%
dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Verificando valores únicos

# %%
dados_emprestimos['tipo_vinculo_usuario'].unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE EXTERNO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
dados_emprestimos['colecao'].unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
dados_emprestimos['biblioteca'].unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
dados_emprestimos['classificação'].unique()
# Out:
# array(['Ciências aplicadas', 'Linguagem. Língua. Linguística',
#        'Ciências sociais', 'Geografia. Biografia. História',
#        'Matemática e ciências naturais', 'Religião',
#        'Generalidades. Ciência e conhecimento', 'Filosofia e psicologia',
#        'Belas artes'], dtype=object)

# %%
def frequencia(variavel):
    ## Função que checa frequência percentual dependendo da variável categórica

    df = pd.DataFrame(dados_emprestimos[variavel].value_counts())
    df.columns = ['quantidade']
    df['percentual'] = round((df['quantidade'] / df['quantidade'].sum())*100,1)

    return df

frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1593703        77.9
# ALUNO DE PÓS-GRADUAÇÃO               298714        14.6
# DOCENTE                               69544         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       31555         1.5
# ALUNO MÉDIO/TÉCNICO                   27626         1.3
# DOCENTE EXTERNO                       23312         1.1
# USUÁRIO EXTERNO                        2489         0.1
# OUTROS                                    5         0.0

# %% [markdown]
# A princípio, nota-se uma maioria de **alunos de graduação** como público dos empréstimos das bibliotecas, somando cerca de **78%** do percentual total, seguido por alunos de pós-graduação (**14.6%**). Fica evidente que quaiquer esforços de marketing da biblioteca devem focar nessa categoria.

# %%
frequencia('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         2027648        99.1
# Multimeios                                   7900         0.4
# Monografias                                  4013         0.2
# Dissertações                                 2401         0.1
# Obras de Referência                          1929         0.1
# Publicações de Autores do RN                  864         0.0
# Publicações da UFRN                           760         0.0
# Teses                                         713         0.0
# Folhetos                                      269         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# ...

# %% [markdown]
# A coleção **"Acervo circulante"** é a grande maioria, representando quase 100% do acervo dos empréstimos. Nota-se que coleções como *Obras Raras* e *Literatura de Cordel* não foram emprestadas, criando um alerta para o motivo para isso.

# %%
frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1410192        68.9
# Biblioteca Setorial do Centro Ciências da Saúde...      117527         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       76413         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       65622         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       60435         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       45554         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40143         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       31273         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       28728         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       26742         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26733         1.3
# ...

# %% [markdown]
# A **Biblioteca Central Zila Mamede** estar em maioria entre os empréstimos condiz com o esperado, considerando que abriga a maioria das obras. Outras bibliotecas, como **Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz** não receberam nenhum empréstimo, o que pode ser devido a falta de obras no acervo, falta de investimento ou falta de marketing.

# %%
frequencia('classificação')
# Out:
#                                        quantidade  percentual
# classificação
# Ciências aplicadas                        1413982        69.1
# Ciências sociais                           364035        17.8
# Matemática e ciências naturais              66173         3.2
# Generalidades. Ciência e conhecimento       61188         3.0
# Religião                                    60955         3.0
# Filosofia e psicologia                      59298         2.9
# Geografia. Biografia. História               7267         0.4
# Belas artes                                  7220         0.4
# Linguagem. Língua. Linguística               6830         0.3

# %% [markdown]
# **Ciências aplicadas** representa mais de 50% dos empréstimos, o que pode estar relacionado a quantidade de alunos de graduação da área ou a quantidade ampla no acervo dessa categoria. Percebe-se que **Belas Artes** e **Linguagem. Língua. Linguística** estão em minoria, o que pode estar relacionado tanto a falta de estímulo e marketing, quanto a quantidade de alunos na área.

# %% [markdown]
# ## Day 5 - Análise exploratória de dados e Boxplot

# %%
dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
alunos_graduacao = dados_emprestimos[dados_emprestimos['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO']
colecao_counts = alunos_graduacao['colecao'].value_counts()
colecao_mais_frequente = colecao_counts.idxmax()
colecao_mais_frequente
# Out:
# 'Acervo Circulante'

# %% [markdown]
# A coleção de maior frequência entre **Alunos de Graduação** é **Acervo Circulante**, portanto, analisar a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 dessa coleção.

# %%
graduacao_acervo_circulante = alunos_graduacao[alunos_graduacao['colecao'] == 'Acervo Circulante']
graduacao_acervo_circulante = pd.DataFrame(graduacao_acervo_circulante)
graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(graduacao_acervo_circulante['data_emprestimo'])
graduacao_acervo_circulante['mes'] = graduacao_acervo_circulante['data_emprestimo'].dt.month
graduacao_acervo_circulante['ano'] = graduacao_acervo_circulante['data_emprestimo'].dt.year
graduacao_acervo_circulante = graduacao_acervo_circulante.loc[:,['ano','mes']]
graduacao_acervo_circulante = graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 115  2016    1        2672
# 116  2017    1        2671
# 117  2019    1        2276
# 118  2019   12        1980
# 119  2011    1         809
#
# [120 rows x 3 columns]

# %%
alunos_posgraduacao = dados_emprestimos[dados_emprestimos['tipo_vinculo_usuario'] == 'ALUNO DE PÓS-GRADUAÇÃO']
colecao_counts = alunos_posgraduacao['colecao'].value_counts()
colecao_mais_frequente = colecao_counts.idxmax()
colecao_mais_frequente
# Out:
# 'Acervo Circulante'

# %% [markdown]
# A coleção mais frequente entre alunos de **Pós-Graduação** também é o **Acervo Circulante**.

# %%
posgraduacao_acervo_circulante = alunos_posgraduacao[alunos_posgraduacao['colecao'] == 'Acervo Circulante']
posgraduacao_acervo_circulante = pd.DataFrame(posgraduacao_acervo_circulante)
posgraduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(posgraduacao_acervo_circulante['data_emprestimo'])
posgraduacao_acervo_circulante['mes'] = posgraduacao_acervo_circulante['data_emprestimo'].dt.month
posgraduacao_acervo_circulante['ano'] = posgraduacao_acervo_circulante['data_emprestimo'].dt.year
posgraduacao_acervo_circulante = posgraduacao_acervo_circulante.loc[:,['ano','mes']]
posgraduacao_acervo_circulante = posgraduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
posgraduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 115  2018   12        1382
# 116  2010   12        1275
# 117  2010    1        1106
# 118  2019   12        1069
# 119  2011    1         465
#
# [120 rows x 3 columns]

# %% [markdown]
# ### Plotando boxplot de da distribuição dos empréstimos mensais realizados pelos alunos de graduação  e pós-graduação na coleção do acervo circulante

# %% [markdown]
# Função para geração de bloxpot

# %%
def boxplot(dataset, x, y, subtitulo):
    
  sns.set_theme(palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(14,10))  

  ax = sns.boxplot(y=y, x=x, data = dataset, color = '#5B7A8E')
  plt.ylim(0,max(dataset[y])*1.1) 
  plt.xticks(fontsize=12, rotation=30)  
  ax.set(xlabel=None,ylabel=None)
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
  ax.set_title("Distribuição dos empréstimos mensais"+"\n",size=16,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')  
  ax=ax

# %% [markdown]
# ### Alunos de graduação

# %%
boxplot(graduacao_acervo_circulante, 'ano', 'quantidade', 'Alunos de graduação no acervo circulante')

# %% [markdown]
# Nota-se que a quantidade empréstimos oscila durante os meses do ano entre os alunos de graduação, que representam também a grande maioria do público de empréstimos da biblioteca. É possível observar um declínio quase contínuo entre 2017 e 2019.

# %% [markdown]
# ### Alunos de pós-graduação

# %%
boxplot(posgraduacao_acervo_circulante, 'ano', 'quantidade', 'Alunos de pós-graduação no acervo circulante')

# %% [markdown]
# O boxplot dos alunos de pós-graduação mostra um aumento na mediana dos empréstimos de 2010 até 2014, seguido de uma estabilidade até 2017 e uma ligeira diminuição a partir de 2018. A queda a partir de 2018 também está presente no gráfico de graduação, podendo ter uma causa semelhante.

# %% [markdown]
# ## Day 6 - JSON, Excel e Pivot_table

# %% [markdown]
# ### Lendo arquivos xlsx (Excel)

# %%
alunos_ate_2010 = pd.read_excel('Datasets\matricula_alunos.xlsx',sheet_name='Até 2010',skiprows=1)
alunos_ate_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %%
alunos_pos_2010 = pd.read_excel('Datasets\matricula_alunos.xlsx',sheet_name='Após 2010',skiprows=1)
alunos_pos_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
alunos_ate_2010.columns = ['matricula_ou_siape', 'tipo_vinculo_usuario', 'curso'] # Colunas correspondentes no banco de dados sendo usado
alunos_ate_2010
# Out:
#       matricula_ou_siape tipo_vinculo_usuario  \
# 0           1.900017e+08   ALUNO DE GRADUAÇÃO
# 1           1.990145e+08   ALUNO DE GRADUAÇÃO
# 2           1.997357e+08   ALUNO DE GRADUAÇÃO
# 3           1.998124e+08   ALUNO DE GRADUAÇÃO
# 4           1.998237e+08   ALUNO DE GRADUAÇÃO
# ...                  ...                  ...
# 7721        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7722        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7723        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7724        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7725        2.009075e+09   ALUNO DE GRADUAÇÃO
#
#                                       curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %%
alunos_pos_2010.columns = ['matricula_ou_siape', 'tipo_vinculo_usuario', 'curso']
alunos_pos_2010.head()
# Out:
#    matricula_ou_siape tipo_vinculo_usuario                 curso
# 0        2.010000e+09   ALUNO DE GRADUAÇÃO               DIREITO
# 1        2.010000e+09   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 2        2.010001e+09   ALUNO DE GRADUAÇÃO    ENGENHARIA QUÍMICA
# 3        2.010003e+09   ALUNO DE GRADUAÇÃO  ENGENHARIA AMBIENTAL
# 4        2.010003e+09   ALUNO DE GRADUAÇÃO             GEOGRAFIA

# %% [markdown]
# Unindo dados xlsx em única tabela

# %%
excel_data = pd.concat([alunos_ate_2010, alunos_graduacao],ignore_index=True)
excel_data = excel_data[['matricula_ou_siape', 'tipo_vinculo_usuario', 'curso']]
excel_data
# Out:
#         matricula_ou_siape tipo_vinculo_usuario                curso
# 0              190001688.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1              199014489.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2              199735674.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3              199812431.0   ALUNO DE GRADUAÇÃO               LETRAS
# 4              199823670.0   ALUNO DE GRADUAÇÃO             ECOLOGIA
# ...                    ...                  ...                  ...
# 1601424      20180003697.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601425      20170131020.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601426      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601427      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601428      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
#
# [1601429 rows x 3 columns]

# %%
excel_data['matricula_ou_siape'] = (excel_data['matricula_ou_siape']).astype(str)
excel_data
# Out:
#         matricula_ou_siape tipo_vinculo_usuario                curso
# 0              190001688.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1              199014489.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2              199735674.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3              199812431.0   ALUNO DE GRADUAÇÃO               LETRAS
# 4              199823670.0   ALUNO DE GRADUAÇÃO             ECOLOGIA
# ...                    ...                  ...                  ...
# 1601424      20180003697.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601425      20170131020.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601426      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601427      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
# 1601428      20190064874.0   ALUNO DE GRADUAÇÃO                  NaN
#
# [1601429 rows x 3 columns]

# %% [markdown]
# Agora que estão todos os dados xlsx importados, ler dados JSON.

# %% [markdown]
# ### Lendo arquivo JSON

# %%
json_data = pd.read_json('Datasets\cadastro_alunos.json')
json_data
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
from io import StringIO
json_string = json_data['registros'][0]
json_io = StringIO(json_string)
graduacao_json = pd.read_json(json_io)
graduacao_json
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %% [markdown]
# Como o foco é nos alunos de graduação, não vou extrair os outros dados (de alunos de pós-graduação).

# %% [markdown]
# Modificando os tipos de dados para garantir que estão no mesmo formato do banco de dados base.

# %%
graduacao_json['matricula_ou_siape'] = graduacao_json['matricula_ou_siape'].astype(str)
graduacao_json
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                   curso
# 0             2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1              200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2              200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3              200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4              200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                  ...                  ...                     ...
# 62797        20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798        20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799        20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800        20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801        20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
cursos_vs_alunos = pd.concat([excel_data, graduacao_json], ignore_index=True)
cursos_vs_alunos
# Out:
#         matricula_ou_siape tipo_vinculo_usuario                 curso
# 0              190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1              199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2              199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3              199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4              199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                    ...                  ...                   ...
# 1664226        20200012706   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 1664227        20200039601   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 1664228        20200132517   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 1664229        20200009344   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 1664230        20200090284   ALUNO DE GRADUAÇÃO               DIREITO
#
# [1664231 rows x 3 columns]

# %% [markdown]
# ### Calculando a quantidade de empréstimos realizados entre 2015 e 2020 por cada curso de graduação avaliado

# %%
emprestimos_pos_2015 = dados_emprestimos.query("tipo_vinculo_usuario == 'ALUNO DE GRADUAÇÃO'")
emprestimos_pos_2015 = emprestimos_pos_2015.loc[:,['matricula_ou_siape','data_emprestimo']]
emprestimos_pos_2015['data_emprestimo'] = pd.to_datetime(emprestimos_pos_2015['data_emprestimo'])
emprestimos_pos_2015 = emprestimos_pos_2015.query('data_emprestimo > 2015')
emprestimos_pos_2015 = emprestimos_pos_2015.reset_index(drop=True)
emprestimos_pos_2015
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013021576.0 2015-01-02 09:16:49.566
# 1            2014026648.0 2015-01-02 09:44:42.808
# 2            2014026648.0 2015-01-02 09:44:43.127
# 3            2010049586.0 2015-01-02 10:11:09.837
# 4            2014021454.0 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 769461      20180003697.0 2019-12-30 16:55:28.439
# 769462      20170131020.0 2019-12-30 17:32:06.254
# 769463      20190064874.0 2019-12-30 17:48:52.962
# 769464      20190064874.0 2019-12-30 17:48:52.998
# 769465      20190064874.0 2019-12-30 17:48:53.039
#
# [769466 rows x 2 columns]

# %% [markdown]
# Retirando valores nulos

# %%
emprestimos_pos_2015 = emprestimos_pos_2015.dropna()
emprestimos_pos_2015
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013021576.0 2015-01-02 09:16:49.566
# 1            2014026648.0 2015-01-02 09:44:42.808
# 2            2014026648.0 2015-01-02 09:44:43.127
# 3            2010049586.0 2015-01-02 10:11:09.837
# 4            2014021454.0 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 769461      20180003697.0 2019-12-30 16:55:28.439
# 769462      20170131020.0 2019-12-30 17:32:06.254
# 769463      20190064874.0 2019-12-30 17:48:52.962
# 769464      20190064874.0 2019-12-30 17:48:52.998
# 769465      20190064874.0 2019-12-30 17:48:53.039
#
# [769466 rows x 2 columns]

# %% [markdown]
# ### Separando a quantidade por cursos selecionados

# %%
emprestimos_por_curso = cursos_vs_alunos.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
emprestimos_por_curso
# Out:
#         matricula_ou_siape tipo_vinculo_usuario             curso
# 8              200031011.0   ALUNO DE GRADUAÇÃO           DIREITO
# 9              200045080.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15             200115053.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18             200123382.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19             200123730.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                    ...                  ...               ...
# 1664218        20200097481   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 1664225        20200107087   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 1664226        20200012706   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 1664229        20200009344   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 1664230        20200090284   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18420 rows x 3 columns]

# %% [markdown]
# ### Merge dos datasets

# %%
emprestimos_pos_2015 = pd.DataFrame(emprestimos_pos_2015)
emprestimos_por_curso = pd.DataFrame(emprestimos_por_curso)
emprestimos_por_curso = emprestimos_pos_2015.merge(emprestimos_por_curso)
emprestimos_por_curso
# Out:
#     matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0         2008022170.0 2015-01-07 15:29:14.542   ALUNO DE GRADUAÇÃO
# 1         2008022170.0 2015-01-07 15:29:14.766   ALUNO DE GRADUAÇÃO
# 2         2008022170.0 2015-01-07 15:29:14.994   ALUNO DE GRADUAÇÃO
# 3         2008021386.0 2015-01-07 15:34:31.020   ALUNO DE GRADUAÇÃO
# 4         2008021386.0 2015-01-07 15:34:31.246   ALUNO DE GRADUAÇÃO
# ..                 ...                     ...                  ...
# 439       2008003426.0 2017-10-21 11:16:36.373   ALUNO DE GRADUAÇÃO
# 440       2008003426.0 2017-10-21 11:16:36.404   ALUNO DE GRADUAÇÃO
# 441       2008003426.0 2017-10-21 11:16:36.436   ALUNO DE GRADUAÇÃO
# 442       2009040228.0 2017-11-27 20:33:36.010   ALUNO DE GRADUAÇÃO
# 443       2009040228.0 2017-11-27 20:33:36.054   ALUNO DE GRADUAÇÃO
#
#                   curso
# 0    COMUNICAÇÃO SOCIAL
# 1    COMUNICAÇÃO SOCIAL
# 2    COMUNICAÇÃO SOCIAL
# 3    COMUNICAÇÃO SOCIAL
# ...

# %%
emprestimos_por_curso.data_emprestimo = emprestimos_por_curso.data_emprestimo.dt.year
relacao_curso_emprestimos = emprestimos_por_curso.iloc[:,[1,3]].value_counts().reset_index()
relacao_curso_emprestimos.columns = ['Ano','Curso','Quantidade de empréstimos']
relacao_curso_emprestimos
# Out:
#      Ano               Curso  Quantidade de empréstimos
# 0   2015    CIÊNCIAS SOCIAIS                        119
# 1   2015  COMUNICAÇÃO SOCIAL                         90
# 2   2015             DIREITO                         85
# 3   2015     BIBLIOTECONOMIA                         68
# 4   2016             DIREITO                         19
# 5   2016    CIÊNCIAS SOCIAIS                         15
# 6   2016     BIBLIOTECONOMIA                         13
# 7   2017    CIÊNCIAS SOCIAIS                         12
# 8   2017     BIBLIOTECONOMIA                          9
# 9   2016  COMUNICAÇÃO SOCIAL                          7
# 10  2017             DIREITO                          5
# 11  2017  COMUNICAÇÃO SOCIAL                          2

# %% [markdown]
# ## Pivot Table

# %%
pivot_emprestimos_por_curso = relacao_curso_emprestimos.pivot_table(
        index = 'Curso',
        columns = 'Ano',
        values = 'Quantidade de empréstimos',
        aggfunc= 'sum',
        margins = True,
        margins_name = 'TOTAL',
)
pivot_emprestimos_por_curso
# Out:
# Ano                 2015  2016  2017  TOTAL
# Curso
# BIBLIOTECONOMIA       68    13     9     90
# CIÊNCIAS SOCIAIS     119    15    12    146
# COMUNICAÇÃO SOCIAL    90     7     2     99
# DIREITO               85    19     5    109
# TOTAL                362    54    28    444
